# %%
from Bio.PDB import *    # create basic analytic functions
import numpy as np

def seq_getter(record):  # get sequence data (whole sequences and sequences in chains)

    seq_combined = []
    seq_in_chains = []
    

     # run parser
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure('struct', record)    

     # iterate each model, chain, and residue
     # printing out the sequence for each chain
    
    i = 1
    for model in structure:
        for chain in model:
            i += 1
            seq = []

            for residue in chain:

                if residue.resname != "HOH":   # don't include HOH 
                    seq.append(residue.resname) # for list of separate chains
                    seq_combined.append(residue.resname)
            seq_in_chains.append(seq)    # for list of separate chains

            
    return seq_combined, seq_in_chains


def check(filename):  # get amount of helix and sheets for pdb file
    f = open(filename)
    helix_count = 0
    sheet_count = 0
    for i in f:
        if "HELIX  " in i:
            helix_count = helix_count + 1
        elif "SHEET   " in i:
            sheet_count = sheet_count +1
            
        
    f.close()
        
    return helix_count, sheet_count


def get_natural_proteins(input_sequences):
    acids = ['CYS', 'ASP', 'SER', 'GLN', 'LYS', 'ILE', 'PRO', 'THR', 'PHE', 'ASN', 'GLY', 'HIS', 'LEU', 'ARG', 'TRP', 'ALA', 'VAL', 'GLU', 'TYR', 'MET']

    sequences = []
    index = []
    counter = 0

    for sequence in input_sequences:
        for acid in sequence:
            if acid not in acids:
                break
        else:
            sequences.append(sequence)
            index.append(counter)
        counter += 1
    
    return sequences, index

def convert_sequences(sequences):

    d3to1 = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
     'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
     'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
     'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}

    new_sequences = []
    translated_seq= ""

    for sequence in sequences:
        for j in sequence:
            translated_seq = translated_seq + d3to1[j]

        new_sequences.append(translated_seq)
        translated_seq= ""
        
    return new_sequences

# %%
# FUNCTION TO GET PROTEIN STRUCTURES

import os, glob, time

def protein_info(directory, total_files):  # inputs: directory, number of files desired
    helices = []
    sheets = []
    sequences = []
    name = []
    length = []
    chains = []

    t0 = time.time()
    counter = 0
    
    for filename in glob.glob(directory):
        f = os.path.join(directory, filename)

        # checking if it is a file
        if os.path.isfile(f):
            counts = check(f)  # getting the number of sheets and helices
            sequence_data = seq_getter(f) # getting the sequence data
            
            helices.append(counts[0])
            sheets.append(counts[1])
            sequences.append(sequence_data[0])
            name.append(filename)
            length.append(len(sequence_data[0]))
            chains.append(len(sequence_data[1]))

            counter = counter + 1
            print(round(counter/total_files*100, 2), "% done", "after", round((time.time()-t0)/60, 1), "minutes")
        
        if counter == total_files:   
            break
                
    return name, length, chains, helices, sheets, sequences # output


directory = "/Volumes/UCG Hard D./PDB Files/pdb//*//*.ent"

data = protein_info(directory, 10000) 

names = np.array(data[0])
length = np.array(data[1])
chains = np.array(data[2])
helices = np.array(data[3])
sheets = np.array(data[4])
sequences = np.array(data[5])
# Out:
# 0.01 % done after 0.1 minutes
# 0.02 % done after 0.1 minutes
# 0.03 % done after 0.1 minutes
# 0.04 % done after 0.1 minutes
# 0.05 % done after 0.1 minutes
# 0.06 % done after 0.1 minutes
# 0.07 % done after 0.1 minutes
# 0.08 % done after 0.1 minutes
# 0.09 % done after 0.1 minutes
# 0.1 % done after 0.1 minutes
# 0.11 % done after 0.1 minutes
# 0.12 % done after 0.1 minutes
# 0.13 % done after 0.1 minutes
# 0.14 % done after 0.1 minutes
# 0.15 % done after 0.1 minutes
# 0.16 % done after 0.1 minutes
# 0.17 % done after 0.1 minutes
# 0.18 % done after 0.1 minutes
# 0.19 % done after 0.1 minutes
# 0.2 % done after 0.1 minutes
# 0.21 % done after 0.1 minutes
# 0.22 % done after 0.1 minutes
# 0.23 % done after 0.2 minutes
# 0.24 % done after 0.2 minutes
# 0.25 % done after 0.2 minutes
# 0.26 % done after 0.2 minutes
# 0.27 % done after 0.2 minutes
# 0.28 % done after 0.2 minutes
# 0.29 % done after 0.2 minutes
# 0.3 % done after 0.2 minutes
# 0.31 % done after 0.2 minutes
# 0.32 % done after 0.2 minutes
# 0.33 % done after 0.2 minutes
# 0.34 % done after 0.2 minutes
# 0.35 % done after 0.2 minutes
# 0.36 % done after 0.2 minutes
# 0.37 % done after 0.2 minutes
# 0.38 % done after 0.2 minutes
# 0.39 % done after 0.2 minutes
# 0.4 % done after 0.2 minutes
# 0.41 % done after 0.2 minutes
# 0.42 % done after 0.2 minutes
# 0.43 % done after 0.2 minutes
# 0.44 % done after 0.2 minutes
# 0.45 % done after 0.2 minutes
# 0.46 % done after 0.2 minutes
# 0.47 % done after 0.2 minutes
# 0.48 % done after 0.2 minutes
# 0.49 % done after 0.2 minutes
# 0.5 % done after 0.2 minutes
# 0.51 % done after 0.2 minutes
# 0.52 % done after 0.2 minutes
# 0.53 % done after 0.2 minutes
# 0.54 % done after 0.2 minutes
# 0.55 % done after 0.2 minutes
# 0.56 % done after 0.2 minutes
# 0.57 % done after 0.2 minutes
# 0.58 % done after 0.2 minutes
# 0.59 % done after 0.2 minutes
# 0.6 % done after 0.2 minutes
# 0.61 % done after 0.2 minutes
# 0.62 % done after 0.2 minutes
# 0.63 % done after 0.2 minutes
# 0.64 % done after 0.2 minutes
# 0.65 % done after 0.2 minutes
# 0.66 % done after 0.2 minutes
# 0.67 % done after 0.2 minutes
# 0.68 % done after 0.2 minutes
# 0.69 % done after 0.2 minutes
# 0.7 % done after 0.2 minutes
# 0.71 % done after 0.2 minutes
# 0.72 % done after 0.2 minutes
# 0.73 % done after 0.2 minutes
# 0.74 % done after 0.2 minutes
# 0.75 % done after 0.2 minutes
# 0.76 % done after 0.2 minutes
# 0.77 % done after 0.2 minutes
# 0.78 % done after 0.2 minutes
# 0.79 % done after 0.2 minutes
# 0.8 % done after 0.2 minutes
# 0.81 % done after 0.2 minutes
# 0.82 % done after 0.2 minutes
# 0.83 % done after 0.2 minutes
# 0.84 % done after 0.2 minutes
# 0.85 % done after 0.2 minutes
# 0.86 % done after 0.2 minutes
# 0.87 % done after 0.2 minutes
# 0.88 % done after 0.2 minutes
# 0.89 % done after 0.2 minutes
# 0.9 % done after 0.2 minutes
# 0.91 % done after 0.2 minutes
# 0.92 % done after 0.2 minutes
# 0.93 % done after 0.2 minutes
# 0.94 % done after 0.2 minutes
# 0.95 % done after 0.2 minutes
# 0.96 % done after 0.2 minutes
# 0.97 % done after 0.2 minutes
# 0.98 % done after 0.2 minutes
# 0.99 % done after 0.2 minutes
# 1.0 % done after 0.2 minutes
# 1.01 % done after 0.2 minutes
# 1.02 % done after 0.2 minutes
# 1.03 % done after 0.2 minutes
# 1.04 % done after 0.2 minutes
# 1.05 % done after 0.2 minutes
# 1.06 % done after 0.2 minutes
# 1.07 % done after 0.2 minutes
# 1.08 % done after 0.2 minutes
# 1.09 % done after 0.2 minutes
# 1.1 % done after 0.2 minutes
# 1.11 % done after 0.2 minutes
# 1.12 % done after 0.2 minutes
# 1.13 % done after 0.2 minutes
# 1.14 % done after 0.2 minutes
# 1.15 % done after 0.2 minutes
# 1.16 % done after 0.2 minutes
# 1.17 % done after 0.2 minutes
# 1.18 % done after 0.2 minutes
# 1.19 % done after 0.2 minutes
# 1.2 % done after 0.2 minutes
# 1.21 % done after 0.2 minutes
# 1.22 % done after 0.2 minutes
# 1.23 % done after 0.2 minutes
# 1.24 % done after 0.2 minutes
# 1.25 % done after 0.2 minutes
# 1.26 % done after 0.2 minutes
# 1.27 % done after 0.2 minutes
# 1.28 % done after 0.2 minutes
# 1.29 % done after 0.2 minutes
# 1.3 % done after 0.2 minutes
# 1.31 % done after 0.2 minutes
# 1.32 % done after 0.2 minutes
# 1.33 % done after 0.2 minutes
# 1.34 % done after 0.2 minutes
# 1.35 % done after 0.2 minutes
# 1.36 % done after 0.2 minutes
# 1.37 % done after 0.2 minutes
# 1.38 % done after 0.2 minutes
# 1.39 % done after 0.2 minutes
# 1.4 % done after 0.2 minutes
# 1.41 % done after 0.2 minutes
# 1.42 % done after 0.2 minutes
# 1.43 % done after 0.2 minutes
# 1.44 % done after 0.2 minutes
# 1.45 % done after 0.2 minutes
# 1.46 % done after 0.2 minutes
# 1.47 % done after 0.2 minutes
# 1.48 % done after 0.2 minutes
# 1.49 % done after 0.2 minutes
# 1.5 % done after 0.2 minutes
# 1.51 % done after 0.2 minutes
# 1.52 % done after 0.2 minutes
# 1.53 % done after 0.2 minutes
# 1.54 % done after 0.2 minutes
# 1.55 % done after 0.2 minutes
# 1.56 % done after 0.2 minutes
# 1.57 % done after 0.2 minutes
# 1.58 % done after 0.2 minutes
# 1.59 % done after 0.2 minutes
# 1.6 % done after 0.2 minutes
# 1.61 % done after 0.2 minutes
# 1.62 % done after 0.2 minutes
# 1.63 % done after 0.2 minutes
# 1.64 % done after 0.2 minutes
# 1.65 % done after 0.2 minutes
# 1.66 % done after 0.2 minutes
# 1.67 % done after 0.2 minutes
# 1.68 % done after 0.2 minutes
# 1.69 % done after 0.2 minutes
# 1.7 % done after 0.2 minutes
# 1.71 % done after 0.2 minutes
# 1.72 % done after 0.2 minutes
# 1.73 % done after 0.2 minutes
# 1.74 % done after 0.2 minutes
# 1.75 % done after 0.2 minutes
# 1.76 % done after 0.2 minutes
# 1.77 % done after 0.2 minutes
# 1.78 % done after 0.2 minutes
# 1.79 % done after 0.2 minutes
# 1.8 % done after 0.2 minutes
# 1.81 % done after 0.2 minutes
# 1.82 % done after 0.2 minutes
# 1.83 % done after 0.2 minutes
# 1.84 % done after 0.2 minutes
# 1.85 % done after 0.2 minutes
# 1.86 % done after 0.2 minutes
# 1.87 % done after 0.2 minutes
# 1.88 % done after 0.2 minutes
# 1.89 % done after 0.2 minutes
# 1.9 % done after 0.2 minutes
# 1.91 % done after 0.2 minutes
# 1.92 % done after 0.2 minutes
# 1.93 % done after 0.2 minutes
# 1.94 % done after 0.2 minutes
# 1.95 % done after 0.2 minutes
# 1.96 % done after 0.2 minutes
# 1.97 % done after 0.2 minutes
# 1.98 % done after 0.2 minutes
# 1.99 % done after 0.2 minutes
# 2.0 % done after 0.2 minutes
# 2.01 % done after 0.2 minutes
# 2.02 % done after 0.2 minutes
# 2.03 % done after 0.2 minutes
# 2.04 % done after 0.2 minutes
# 2.05 % done after 0.2 minutes
# 2.06 % done after 0.2 minutes
# 2.07 % done after 0.2 minutes
# 2.08 % done after 0.2 minutes
# 2.09 % done after 0.2 minutes
# 2.1 % done after 0.2 minutes
# 2.11 % done after 0.2 minutes
# 2.12 % done after 0.2 minutes
# 2.13 % done after 0.2 minutes
# 2.14 % done after 0.2 minutes
# 2.15 % done after 0.2 minutes
# 2.16 % done after 0.2 minutes
# 2.17 % done after 0.2 minutes
# 2.18 % done after 0.2 minutes
# 2.19 % done after 0.2 minutes
# 2.2 % done after 0.2 minutes
# 2.21 % done after 0.2 minutes
# 2.22 % done after 0.2 minutes
# 2.23 % done after 0.2 minutes
# 2.24 % done after 0.2 minutes
# 2.25 % done after 0.2 minutes
# 2.26 % done after 0.2 minutes
# 2.27 % done after 0.2 minutes
# 2.28 % done after 0.2 minutes
# 2.29 % done after 0.2 minutes
# 2.3 % done after 0.2 minutes
# 2.31 % done after 0.2 minutes
# 2.32 % done after 0.2 minutes
# 2.33 % done after 0.2 minutes
# 2.34 % done after 0.2 minutes
# 2.35 % done after 0.2 minutes
# 2.36 % done after 0.2 minutes
# 2.37 % done after 0.2 minutes
# 2.38 % done after 0.2 minutes
# 2.39 % done after 0.2 minutes
# 2.4 % done after 0.2 minutes
# 2.41 % done after 0.2 minutes
# 2.42 % done after 0.2 minutes
# 2.43 % done after 0.2 minutes
# 2.44 % done after 0.2 minutes
# 2.45 % done after 0.2 minutes
# 2.46 % done after 0.2 minutes
# 2.47 % done after 0.2 minutes
# 2.48 % done after 0.2 minutes
# 2.49 % done after 0.2 minutes
# 2.5 % done after 0.2 minutes
# 2.51 % done after 0.2 minutes
# 2.52 % done after 0.2 minutes
# 2.53 % done after 0.2 minutes
# 2.54 % done after 0.2 minutes
# 2.55 % done after 0.2 minutes
# 2.56 % done after 0.2 minutes
# 2.57 % done after 0.2 minutes
# 2.58 % done after 0.2 minutes
# 2.59 % done after 0.2 minutes
# 2.6 % done after 0.2 minutes
# 2.61 % done after 0.2 minutes
# 2.62 % done after 0.2 minutes
# 2.63 % done after 0.2 minutes
# 2.64 % done after 0.3 minutes
# 2.65 % done after 0.3 minutes
# 2.66 % done after 0.3 minutes
# 2.67 % done after 0.3 minutes
# 2.68 % done after 0.3 minutes
# 2.69 % done after 0.3 minutes
# 2.7 % done after 0.3 minutes
# 2.71 % done after 0.3 minutes
# 2.72 % done after 0.3 minutes
# 2.73 % done after 0.3 minutes
# 2.74 % done after 0.3 minutes
# 2.75 % done after 0.3 minutes
# 2.76 % done after 0.3 minutes
# 2.77 % done after 0.3 minutes
# 2.78 % done after 0.3 minutes
# 2.79 % done after 0.3 minutes
# 2.8 % done after 0.3 minutes
# 2.81 % done after 0.3 minutes
# 2.82 % done after 0.3 minutes
# 2.83 % done after 0.3 minutes
# 2.84 % done after 0.3 minutes
# 2.85 % done after 0.3 minutes
# 2.86 % done after 0.3 minutes
# 2.87 % done after 0.3 minutes
# 2.88 % done after 0.3 minutes
# 2.89 % done after 0.3 minutes
# 2.9 % done after 0.3 minutes
# 2.91 % done after 0.3 minutes
# 2.92 % done after 0.3 minutes
# 2.93 % done after 0.3 minutes
# 2.94 % done after 0.3 minutes
# 2.95 % done after 0.3 minutes
# 2.96 % done after 0.3 minutes
# 2.97 % done after 0.3 minutes
# 2.98 % done after 0.3 minutes
# 2.99 % done after 0.3 minutes
# 3.0 % done after 0.3 minutes
# 3.01 % done after 0.3 minutes
# 3.02 % done after 0.3 minutes
# 3.03 % done after 0.3 minutes
# 3.04 % done after 0.3 minutes
# 3.05 % done after 0.3 minutes
# 3.06 % done after 0.3 minutes
# 3.07 % done after 0.3 minutes
# 3.08 % done after 0.3 minutes
# 3.09 % done after 0.3 minutes
# 3.1 % done after 0.3 minutes
# 3.11 % done after 0.3 minutes
# 3.12 % done after 0.3 minutes
# 3.13 % done after 0.3 minutes
# 3.14 % done after 0.3 minutes
# 3.15 % done after 0.3 minutes
# 3.16 % done after 0.3 minutes
# 3.17 % done after 0.3 minutes
# 3.18 % done after 0.3 minutes
# 3.19 % done after 0.3 minutes
# 3.2 % done after 0.3 minutes
# 3.21 % done after 0.3 minutes
# 3.22 % done after 0.3 minutes
# 3.23 % done after 0.3 minutes
# 3.24 % done after 0.3 minutes
# 3.25 % done after 0.3 minutes
# 3.26 % done after 0.3 minutes
# 3.27 % done after 0.3 minutes
# 3.28 % done after 0.3 minutes
# 3.29 % done after 0.3 minutes
# 3.3 % done after 0.3 minutes
# 3.31 % done after 0.3 minutes
# 3.32 % done after 0.3 minutes
# 3.33 % done after 0.3 minutes
# 3.34 % done after 0.3 minutes
# 3.35 % done after 0.3 minutes
# 3.36 % done after 0.3 minutes
# 3.37 % done after 0.3 minutes
# 3.38 % done after 0.3 minutes
# 3.39 % done after 0.3 minutes
# 3.4 % done after 0.3 minutes
# 3.41 % done after 0.3 minutes
# 3.42 % done after 0.3 minutes
# 3.43 % done after 0.3 minutes
# 3.44 % done after 0.3 minutes
# 3.45 % done after 0.3 minutes
# 3.46 % done after 0.3 minutes
# 3.47 % done after 0.3 minutes
# 3.48 % done after 0.3 minutes
# 3.49 % done after 0.3 minutes
# 3.5 % done after 0.3 minutes
# 3.51 % done after 0.3 minutes
# 3.52 % done after 0.3 minutes
# 3.53 % done after 0.3 minutes
# 3.54 % done after 0.3 minutes
# 3.55 % done after 0.3 minutes
# 3.56 % done after 0.3 minutes
# 3.57 % done after 0.3 minutes
# 3.58 % done after 0.3 minutes
# 3.59 % done after 0.3 minutes
# 3.6 % done after 0.3 minutes
# 3.61 % done after 0.3 minutes
# 3.62 % done after 0.3 minutes
# 3.63 % done after 0.3 minutes
# 3.64 % done after 0.3 minutes
# 3.65 % done after 0.3 minutes
# 3.66 % done after 0.3 minutes
# 3.67 % done after 0.3 minutes
# 3.68 % done after 0.3 minutes
# 3.69 % done after 0.3 minutes
# 3.7 % done after 0.3 minutes
# 3.71 % done after 0.3 minutes
# 3.72 % done after 0.3 minutes
# 3.73 % done after 0.3 minutes
# 3.74 % done after 0.3 minutes
# 3.75 % done after 0.3 minutes
# 3.76 % done after 0.3 minutes
# 3.77 % done after 0.3 minutes
# 3.78 % done after 0.3 minutes
# 3.79 % done after 0.3 minutes
# 3.8 % done after 0.3 minutes
# 3.81 % done after 0.3 minutes
# 3.82 % done after 0.3 minutes
# 3.83 % done after 0.3 minutes
# 3.84 % done after 0.3 minutes
# 3.85 % done after 0.3 minutes
# 3.86 % done after 0.3 minutes
# 3.87 % done after 0.3 minutes
# 3.88 % done after 0.3 minutes
# 3.89 % done after 0.3 minutes
# 3.9 % done after 0.3 minutes
# 3.91 % done after 0.3 minutes
# 3.92 % done after 0.3 minutes
# 3.93 % done after 0.3 minutes
# 3.94 % done after 0.3 minutes
# 3.95 % done after 0.3 minutes
# 3.96 % done after 0.3 minutes
# 3.97 % done after 0.3 minutes
# 3.98 % done after 0.3 minutes
# 3.99 % done after 0.3 minutes
# 4.0 % done after 0.3 minutes
# 4.01 % done after 0.3 minutes
# 4.02 % done after 0.3 minutes
# 4.03 % done after 0.3 minutes
# 4.04 % done after 0.3 minutes
# 4.05 % done after 0.3 minutes
# 4.06 % done after 0.3 minutes
# 4.07 % done after 0.3 minutes
# 4.08 % done after 0.3 minutes
# 4.09 % done after 0.3 minutes
# 4.1 % done after 0.3 minutes
# 4.11 % done after 0.3 minutes
# 4.12 % done after 0.3 minutes
# 4.13 % done after 0.3 minutes
# 4.14 % done after 0.3 minutes
# 4.15 % done after 0.3 minutes
# 4.16 % done after 0.3 minutes
# 4.17 % done after 0.3 minutes
# 4.18 % done after 0.3 minutes
# 4.19 % done after 0.3 minutes
# 4.2 % done after 0.3 minutes
# 4.21 % done after 0.3 minutes
# 4.22 % done after 0.3 minutes
# 4.23 % done after 0.3 minutes
# 4.24 % done after 0.3 minutes
# 4.25 % done after 0.3 minutes
# 4.26 % done after 0.3 minutes
# 4.27 % done after 0.3 minutes
# 4.28 % done after 0.3 minutes
# 4.29 % done after 0.3 minutes
# 4.3 % done after 0.3 minutes
# 4.31 % done after 0.3 minutes
# 4.32 % done after 0.3 minutes
# 4.33 % done after 0.3 minutes
# 4.34 % done after 0.3 minutes
# 4.35 % done after 0.3 minutes
# 4.36 % done after 0.3 minutes
# 4.37 % done after 0.3 minutes
# 4.38 % done after 0.3 minutes
# 4.39 % done after 0.3 minutes
# 4.4 % done after 0.3 minutes
# 4.41 % done after 0.3 minutes
# 4.42 % done after 0.3 minutes
# 4.43 % done after 0.3 minutes
# 4.44 % done after 0.3 minutes
# 4.45 % done after 0.3 minutes
# 4.46 % done after 0.3 minutes
# 4.47 % done after 0.3 minutes
# 4.48 % done after 0.3 minutes
# 4.49 % done after 0.3 minutes
# 4.5 % done after 0.3 minutes
# 4.51 % done after 0.3 minutes
# 4.52 % done after 0.3 minutes
# 4.53 % done after 0.3 minutes
# 4.54 % done after 0.3 minutes
# 4.55 % done after 0.3 minutes
# 4.56 % done after 0.3 minutes
# 4.57 % done after 0.3 minutes
# 4.58 % done after 0.3 minutes
# 4.59 % done after 0.3 minutes
# 4.6 % done after 0.3 minutes
# 4.61 % done after 0.3 minutes
# 4.62 % done after 0.3 minutes
# 4.63 % done after 0.3 minutes
# 4.64 % done after 0.3 minutes
# 4.65 % done after 0.3 minutes
# 4.66 % done after 0.3 minutes
# 4.67 % done after 0.3 minutes
# 4.68 % done after 0.3 minutes
# 4.69 % done after 0.3 minutes
# 4.7 % done after 0.3 minutes
# 4.71 % done after 0.3 minutes
# 4.72 % done after 0.3 minutes
# 4.73 % done after 0.3 minutes
# 4.74 % done after 0.3 minutes
# 4.75 % done after 0.3 minutes
# 4.76 % done after 0.3 minutes
# 4.77 % done after 0.3 minutes
# 4.78 % done after 0.3 minutes
# 4.79 % done after 0.3 minutes
# 4.8 % done after 0.3 minutes
# 4.81 % done after 0.3 minutes
# 4.82 % done after 0.3 minutes
# 4.83 % done after 0.3 minutes
# 4.84 % done after 0.3 minutes
# 4.85 % done after 0.3 minutes
# 4.86 % done after 0.3 minutes
# 4.87 % done after 0.3 minutes
# 4.88 % done after 0.3 minutes
# 4.89 % done after 0.3 minutes
# 4.9 % done after 0.3 minutes
# 4.91 % done after 0.3 minutes
# 4.92 % done after 0.3 minutes
# 4.93 % done after 0.3 minutes
# 4.94 % done after 0.3 minutes
# 4.95 % done after 0.3 minutes
# 4.96 % done after 0.3 minutes
# 4.97 % done after 0.3 minutes
# 4.98 % done after 0.3 minutes
# 4.99 % done after 0.3 minutes
# 5.0 % done after 0.3 minutes
# 5.01 % done after 0.3 minutes
# 5.02 % done after 0.3 minutes
# 5.03 % done after 0.3 minutes
# 5.04 % done after 0.3 minutes
# 5.05 % done after 0.3 minutes
# 5.06 % done after 0.3 minutes
# 5.07 % done after 0.3 minutes
# 5.08 % done after 0.3 minutes
# 5.09 % done after 0.3 minutes
# 5.1 % done after 0.3 minutes
# 5.11 % done after 0.3 minutes
# 5.12 % done after 0.3 minutes
# 5.13 % done after 0.3 minutes
# 5.14 % done after 0.3 minutes
# 5.15 % done after 0.3 minutes
# 5.16 % done after 0.3 minutes
# 5.17 % done after 0.3 minutes
# 5.18 % done after 0.3 minutes
# 5.19 % done after 0.3 minutes
# 5.2 % done after 0.3 minutes
# 5.21 % done after 0.3 minutes
# 5.22 % done after 0.3 minutes
# 5.23 % done after 0.3 minutes
# 5.24 % done after 0.3 minutes
# 5.25 % done after 0.3 minutes
# 5.26 % done after 0.3 minutes
# 5.27 % done after 0.3 minutes
# 5.28 % done after 0.3 minutes
# 5.29 % done after 0.3 minutes
# 5.3 % done after 0.3 minutes
# 5.31 % done after 0.3 minutes
# 5.32 % done after 0.3 minutes
# 5.33 % done after 0.3 minutes
# 5.34 % done after 0.3 minutes
# 5.35 % done after 0.3 minutes
# 5.36 % done after 0.3 minutes
# 5.37 % done after 0.3 minutes
# 5.38 % done after 0.3 minutes
# 5.39 % done after 0.4 minutes
# 5.4 % done after 0.4 minutes
# 5.41 % done after 0.4 minutes
# 5.42 % done after 0.4 minutes
# 5.43 % done after 0.4 minutes
# 5.44 % done after 0.4 minutes
# 5.45 % done after 0.4 minutes
# 5.46 % done after 0.4 minutes
# 5.47 % done after 0.4 minutes
# 5.48 % done after 0.4 minutes
# 5.49 % done after 0.4 minutes
# 5.5 % done after 0.4 minutes
# 5.51 % done after 0.4 minutes
# 5.52 % done after 0.4 minutes
# 5.53 % done after 0.4 minutes
# 5.54 % done after 0.4 minutes
# 5.55 % done after 0.4 minutes
# 5.56 % done after 0.4 minutes
# 5.57 % done after 0.4 minutes
# 5.58 % done after 0.4 minutes
# 5.59 % done after 0.4 minutes
# 5.6 % done after 0.4 minutes
# 5.61 % done after 0.4 minutes
# 5.62 % done after 0.4 minutes
# 5.63 % done after 0.4 minutes
# 5.64 % done after 0.4 minutes
# 5.65 % done after 0.4 minutes
# 5.66 % done after 0.4 minutes
# 5.67 % done after 0.4 minutes
# 5.68 % done after 0.4 minutes
# 5.69 % done after 0.4 minutes
# 5.7 % done after 0.4 minutes
# 5.71 % done after 0.4 minutes
# 5.72 % done after 0.4 minutes
# 5.73 % done after 0.4 minutes
# 5.74 % done after 0.4 minutes
# 5.75 % done after 0.4 minutes
# 5.76 % done after 0.4 minutes
# 5.77 % done after 0.4 minutes
# 5.78 % done after 0.4 minutes
# 5.79 % done after 0.4 minutes
# 5.8 % done after 0.4 minutes
# 5.81 % done after 0.4 minutes
# 5.82 % done after 0.4 minutes
# 5.83 % done after 0.4 minutes
# 5.84 % done after 0.4 minutes
# 5.85 % done after 0.4 minutes
# 5.86 % done after 0.4 minutes
# 5.87 % done after 0.4 minutes
# 5.88 % done after 0.4 minutes
# 5.89 % done after 0.4 minutes
# 5.9 % done after 0.4 minutes
# 5.91 % done after 0.4 minutes
# 5.92 % done after 0.4 minutes
# 5.93 % done after 0.4 minutes
# 5.94 % done after 0.4 minutes
# 5.95 % done after 0.4 minutes
# 5.96 % done after 0.4 minutes
# 5.97 % done after 0.4 minutes
# 5.98 % done after 0.4 minutes
# 5.99 % done after 0.4 minutes
# 6.0 % done after 0.4 minutes
# 6.01 % done after 0.4 minutes
# 6.02 % done after 0.4 minutes
# 6.03 % done after 0.4 minutes
# 6.04 % done after 0.4 minutes
# 6.05 % done after 0.4 minutes
# 6.06 % done after 0.4 minutes
# 6.07 % done after 0.4 minutes
# 6.08 % done after 0.4 minutes
# 6.09 % done after 0.4 minutes
# 6.1 % done after 0.4 minutes
# 6.11 % done after 0.4 minutes
# 6.12 % done after 0.4 minutes
# 6.13 % done after 0.4 minutes
# 6.14 % done after 0.4 minutes
# 6.15 % done after 0.4 minutes
# 6.16 % done after 0.4 minutes
# 6.17 % done after 0.4 minutes
# 6.18 % done after 0.4 minutes
# 6.19 % done after 0.4 minutes
# 6.2 % done after 0.4 minutes
# 6.21 % done after 0.5 minutes
# 6.22 % done after 0.5 minutes
# 6.23 % done after 0.5 minutes
# 6.24 % done after 0.5 minutes
# 6.25 % done after 0.5 minutes
# 6.26 % done after 0.5 minutes
# 6.27 % done after 0.5 minutes
# 6.28 % done after 0.5 minutes
# 6.29 % done after 0.5 minutes
# 6.3 % done after 0.5 minutes
# 6.31 % done after 0.5 minutes
# 6.32 % done after 0.5 minutes
# 6.33 % done after 0.5 minutes
# 6.34 % done after 0.5 minutes
# 6.35 % done after 0.5 minutes
# 6.36 % done after 0.5 minutes
# 6.37 % done after 0.5 minutes
# 6.38 % done after 0.5 minutes
# 6.39 % done after 0.5 minutes
# 6.4 % done after 0.5 minutes
# 6.41 % done after 0.5 minutes
# 6.42 % done after 0.5 minutes
# 6.43 % done after 0.5 minutes
# 6.44 % done after 0.5 minutes
# 6.45 % done after 0.5 minutes
# 6.46 % done after 0.5 minutes
# 6.47 % done after 0.5 minutes
# 6.48 % done after 0.5 minutes
# 6.49 % done after 0.5 minutes
# 6.5 % done after 0.5 minutes
# 6.51 % done after 0.5 minutes
# 6.52 % done after 0.5 minutes
# 6.53 % done after 0.5 minutes
# 6.54 % done after 0.5 minutes
# 6.55 % done after 0.5 minutes
# 6.56 % done after 0.5 minutes
# 6.57 % done after 0.5 minutes
# 6.58 % done after 0.5 minutes
# 6.59 % done after 0.5 minutes
# 6.6 % done after 0.5 minutes
# 6.61 % done after 0.5 minutes
# 6.62 % done after 0.5 minutes
# 6.63 % done after 0.5 minutes
# 6.64 % done after 0.5 minutes
# 6.65 % done after 0.5 minutes
# 6.66 % done after 0.5 minutes
# 6.67 % done after 0.5 minutes
# 6.68 % done after 0.5 minutes
# 6.69 % done after 0.5 minutes
# 6.7 % done after 0.5 minutes
# 6.71 % done after 0.5 minutes
# 6.72 % done after 0.5 minutes
# 6.73 % done after 0.5 minutes
# 6.74 % done after 0.5 minutes
# 6.75 % done after 0.5 minutes
# 6.76 % done after 0.5 minutes
# 6.77 % done after 0.5 minutes
# 6.78 % done after 0.5 minutes
# 6.79 % done after 0.5 minutes
# 6.8 % done after 0.5 minutes
# 6.81 % done after 0.5 minutes
# 6.82 % done after 0.6 minutes
# 6.83 % done after 0.6 minutes
# 6.84 % done after 0.6 minutes
# 6.85 % done after 0.6 minutes
# 6.86 % done after 0.6 minutes
# 6.87 % done after 0.6 minutes
# 6.88 % done after 0.6 minutes
# 6.89 % done after 0.6 minutes
# 6.9 % done after 0.6 minutes
# 6.91 % done after 0.6 minutes
# 6.92 % done after 0.6 minutes
# 6.93 % done after 0.6 minutes
# 6.94 % done after 0.6 minutes
# 6.95 % done after 0.6 minutes
# 6.96 % done after 0.6 minutes
# 6.97 % done after 0.6 minutes
# 6.98 % done after 0.6 minutes
# 6.99 % done after 0.6 minutes
# 7.0 % done after 0.6 minutes
# 7.01 % done after 0.6 minutes
# 7.02 % done after 0.6 minutes
# 7.03 % done after 0.7 minutes
# 7.04 % done after 0.7 minutes
# 7.05 % done after 0.7 minutes
# 7.06 % done after 0.7 minutes
# 7.07 % done after 0.7 minutes
# 7.08 % done after 0.7 minutes
# 7.09 % done after 0.7 minutes
# 7.1 % done after 0.7 minutes
# 7.11 % done after 0.7 minutes
# 7.12 % done after 0.7 minutes
# 7.13 % done after 0.7 minutes
# 7.14 % done after 0.7 minutes
# 7.15 % done after 0.7 minutes
# 7.16 % done after 0.7 minutes
# 7.17 % done after 0.7 minutes
# 7.18 % done after 0.7 minutes
# 7.19 % done after 0.7 minutes
# 7.2 % done after 0.7 minutes
# 7.21 % done after 0.7 minutes
# 7.22 % done after 0.7 minutes
# 7.23 % done after 0.7 minutes
# 7.24 % done after 0.7 minutes
# 7.25 % done after 0.7 minutes
# 7.26 % done after 0.7 minutes
# 7.27 % done after 0.7 minutes
# 7.28 % done after 0.7 minutes
# 7.29 % done after 0.7 minutes
# 7.3 % done after 0.7 minutes
# 7.31 % done after 0.7 minutes
# 7.32 % done after 0.7 minutes
# 7.33 % done after 0.7 minutes
# 7.34 % done after 0.7 minutes
# 7.35 % done after 0.8 minutes
# 7.36 % done after 0.8 minutes
# 7.37 % done after 0.8 minutes
# 7.38 % done after 0.8 minutes
# 7.39 % done after 0.8 minutes
# 7.4 % done after 0.8 minutes
# 7.41 % done after 0.8 minutes
# 7.42 % done after 0.8 minutes
# 7.43 % done after 0.8 minutes
# 7.44 % done after 0.8 minutes
# 7.45 % done after 0.8 minutes
# 7.46 % done after 0.8 minutes
# 7.47 % done after 0.8 minutes
# 7.48 % done after 0.8 minutes
# 7.49 % done after 0.8 minutes
# 7.5 % done after 0.8 minutes
# 7.51 % done after 0.8 minutes
# 7.52 % done after 0.8 minutes
# 7.53 % done after 0.8 minutes
# 7.54 % done after 0.8 minutes
# 7.55 % done after 0.8 minutes
# 7.56 % done after 0.8 minutes
# 7.57 % done after 0.8 minutes
# 7.58 % done after 0.8 minutes
# 7.59 % done after 0.8 minutes
# 7.6 % done after 0.8 minutes
# 7.61 % done after 0.8 minutes
# 7.62 % done after 0.8 minutes
# 7.63 % done after 0.8 minutes
# 7.64 % done after 0.8 minutes
# 7.65 % done after 0.8 minutes
# 7.66 % done after 0.8 minutes
# 7.67 % done after 0.8 minutes
# 7.68 % done after 0.8 minutes
# 7.69 % done after 0.8 minutes
# 7.7 % done after 0.8 minutes
# 7.71 % done after 0.8 minutes
# 7.72 % done after 0.8 minutes
# 7.73 % done after 0.8 minutes
# 7.74 % done after 0.8 minutes
# 7.75 % done after 0.8 minutes
# 7.76 % done after 0.8 minutes
# 7.77 % done after 0.8 minutes
# 7.78 % done after 0.8 minutes
# 7.79 % done after 0.8 minutes
# 7.8 % done after 0.8 minutes
# 7.81 % done after 0.8 minutes
# 7.82 % done after 0.8 minutes
# 7.83 % done after 0.8 minutes
# 7.84 % done after 0.9 minutes
# 7.85 % done after 0.9 minutes
# 7.86 % done after 0.9 minutes
# 7.87 % done after 0.9 minutes
# 7.88 % done after 0.9 minutes
# 7.89 % done after 0.9 minutes
# 7.9 % done after 0.9 minutes
# 7.91 % done after 0.9 minutes
# 7.92 % done after 0.9 minutes
# 7.93 % done after 0.9 minutes
# 7.94 % done after 0.9 minutes
# 7.95 % done after 0.9 minutes
# 7.96 % done after 1.0 minutes
# 7.97 % done after 1.0 minutes
# 7.98 % done after 1.0 minutes
# 7.99 % done after 1.0 minutes
# 8.0 % done after 1.0 minutes
# 8.01 % done after 1.0 minutes
# 8.02 % done after 1.0 minutes
# 8.03 % done after 1.0 minutes
# 8.04 % done after 1.0 minutes
# 8.05 % done after 1.0 minutes
# 8.06 % done after 1.0 minutes
# 8.07 % done after 1.0 minutes
# 8.08 % done after 1.0 minutes
# 8.09 % done after 1.0 minutes
# 8.1 % done after 1.0 minutes
# 8.11 % done after 1.0 minutes
# 8.12 % done after 1.0 minutes
# 8.13 % done after 1.0 minutes
# 8.14 % done after 1.0 minutes
# 8.15 % done after 1.0 minutes
# 8.16 % done after 1.0 minutes
# 8.17 % done after 1.0 minutes
# 8.18 % done after 1.0 minutes
# 8.19 % done after 1.0 minutes
# 8.2 % done after 1.0 minutes
# 8.21 % done after 1.0 minutes
# 8.22 % done after 1.0 minutes
# 8.23 % done after 1.0 minutes
# 8.24 % done after 1.0 minutes
# 8.25 % done after 1.0 minutes
# 8.26 % done after 1.0 minutes
# 8.27 % done after 1.0 minutes
# 8.28 % done after 1.0 minutes
# 8.29 % done after 1.0 minutes
# 8.3 % done after 1.0 minutes
# 8.31 % done after 1.0 minutes
# 8.32 % done after 1.0 minutes
# 8.33 % done after 1.0 minutes
# 8.34 % done after 1.0 minutes
# 8.35 % done after 1.0 minutes
# 8.36 % done after 1.0 minutes
# 8.37 % done after 1.0 minutes
# 8.38 % done after 1.0 minutes
# 8.39 % done after 1.0 minutes
# 8.4 % done after 1.0 minutes
# 8.41 % done after 1.0 minutes
# 8.42 % done after 1.0 minutes
# 8.43 % done after 1.0 minutes
# 8.44 % done after 1.0 minutes
# 8.45 % done after 1.0 minutes
# 8.46 % done after 1.0 minutes
# 8.47 % done after 1.0 minutes
# 8.48 % done after 1.0 minutes
# 8.49 % done after 1.0 minutes
# 8.5 % done after 1.0 minutes
# 8.51 % done after 1.0 minutes
# 8.52 % done after 1.0 minutes
# 8.53 % done after 1.0 minutes
# 8.54 % done after 1.0 minutes
# 8.55 % done after 1.0 minutes
# 8.56 % done after 1.0 minutes
# 8.57 % done after 1.0 minutes
# 8.58 % done after 1.0 minutes
# 8.59 % done after 1.0 minutes
# 8.6 % done after 1.0 minutes
# 8.61 % done after 1.0 minutes
# 8.62 % done after 1.0 minutes
# 8.63 % done after 1.0 minutes
# 8.64 % done after 1.0 minutes
# 8.65 % done after 1.0 minutes
# 8.66 % done after 1.0 minutes
# 8.67 % done after 1.1 minutes
# 8.68 % done after 1.1 minutes
# 8.69 % done after 1.1 minutes
# 8.7 % done after 1.1 minutes
# 8.71 % done after 1.1 minutes
# 8.72 % done after 1.1 minutes
# 8.73 % done after 1.1 minutes
# 8.74 % done after 1.1 minutes
# 8.75 % done after 1.1 minutes
# 8.76 % done after 1.1 minutes
# 8.77 % done after 1.1 minutes
# 8.78 % done after 1.1 minutes
# 8.79 % done after 1.1 minutes
# 8.8 % done after 1.1 minutes
# 8.81 % done after 1.1 minutes
# 8.82 % done after 1.1 minutes
# 8.83 % done after 1.1 minutes
# 8.84 % done after 1.1 minutes
# 8.85 % done after 1.1 minutes
# 8.86 % done after 1.1 minutes
# 8.87 % done after 1.1 minutes
# 8.88 % done after 1.1 minutes
# 8.89 % done after 1.1 minutes
# 8.9 % done after 1.1 minutes
# 8.91 % done after 1.1 minutes
# 8.92 % done after 1.1 minutes
# 8.93 % done after 1.1 minutes
# 8.94 % done after 1.1 minutes
# 8.95 % done after 1.1 minutes
# 8.96 % done after 1.1 minutes
# 8.97 % done after 1.1 minutes
# 8.98 % done after 1.1 minutes
# 8.99 % done after 1.1 minutes
# 9.0 % done after 1.1 minutes
# 9.01 % done after 1.1 minutes
# 9.02 % done after 1.1 minutes
# 9.03 % done after 1.1 minutes
# 9.04 % done after 1.1 minutes
# 9.05 % done after 1.1 minutes
# 9.06 % done after 1.1 minutes
# 9.07 % done after 1.2 minutes
# 9.08 % done after 1.2 minutes
# 9.09 % done after 1.2 minutes
# 9.1 % done after 1.2 minutes
# 9.11 % done after 1.2 minutes
# 9.12 % done after 1.2 minutes
# 9.13 % done after 1.2 minutes
# 9.14 % done after 1.2 minutes
# 9.15 % done after 1.2 minutes
# 9.16 % done after 1.2 minutes
# 9.17 % done after 1.2 minutes
# 9.18 % done after 1.2 minutes
# 9.19 % done after 1.2 minutes
# 9.2 % done after 1.2 minutes
# 9.21 % done after 1.2 minutes
# 9.22 % done after 1.2 minutes
# 9.23 % done after 1.2 minutes
# 9.24 % done after 1.2 minutes
# 9.25 % done after 1.2 minutes
# 9.26 % done after 1.2 minutes
# 9.27 % done after 1.2 minutes
# 9.28 % done after 1.2 minutes
# 9.29 % done after 1.2 minutes
# 9.3 % done after 1.2 minutes
# 9.31 % done after 1.2 minutes
# 9.32 % done after 1.2 minutes
# 9.33 % done after 1.2 minutes
# 9.34 % done after 1.2 minutes
# 9.35 % done after 1.2 minutes
# 9.36 % done after 1.2 minutes
# 9.37 % done after 1.2 minutes
# 9.38 % done after 1.2 minutes
# 9.39 % done after 1.2 minutes
# 9.4 % done after 1.2 minutes
# 9.41 % done after 1.2 minutes
# 9.42 % done after 1.2 minutes
# 9.43 % done after 1.2 minutes
# 9.44 % done after 1.2 minutes
# 9.45 % done after 1.2 minutes
# 9.46 % done after 1.2 minutes
# 9.47 % done after 1.2 minutes
# 9.48 % done after 1.3 minutes
# 9.49 % done after 1.3 minutes
# 9.5 % done after 1.3 minutes
# 9.51 % done after 1.3 minutes
# 9.52 % done after 1.3 minutes
# 9.53 % done after 1.3 minutes
# 9.54 % done after 1.3 minutes
# 9.55 % done after 1.3 minutes
# 9.56 % done after 1.3 minutes
# 9.57 % done after 1.3 minutes
# 9.58 % done after 1.3 minutes
# 9.59 % done after 1.3 minutes
# 9.6 % done after 1.3 minutes
# 9.61 % done after 1.3 minutes
# 9.62 % done after 1.3 minutes
# 9.63 % done after 1.3 minutes
# 9.64 % done after 1.3 minutes
# 9.65 % done after 1.3 minutes
# 9.66 % done after 1.3 minutes
# 9.67 % done after 1.3 minutes
# 9.68 % done after 1.3 minutes
# 9.69 % done after 1.3 minutes
# 9.7 % done after 1.3 minutes
# 9.71 % done after 1.3 minutes
# 9.72 % done after 1.3 minutes
# 9.73 % done after 1.3 minutes
# 9.74 % done after 1.3 minutes
# 9.75 % done after 1.3 minutes
# 9.76 % done after 1.3 minutes
# 9.77 % done after 1.3 minutes
# 9.78 % done after 1.3 minutes
# 9.79 % done after 1.3 minutes
# 9.8 % done after 1.3 minutes
# 9.81 % done after 1.3 minutes
# 9.82 % done after 1.3 minutes
# 9.83 % done after 1.3 minutes
# 9.84 % done after 1.3 minutes
# 9.85 % done after 1.3 minutes
# 9.86 % done after 1.3 minutes
# 9.87 % done after 1.3 minutes
# 9.88 % done after 1.3 minutes
# 9.89 % done after 1.3 minutes
# 9.9 % done after 1.3 minutes
# 9.91 % done after 1.3 minutes
# 9.92 % done after 1.3 minutes
# 9.93 % done after 1.3 minutes
# 9.94 % done after 1.3 minutes
# 9.95 % done after 1.3 minutes
# 9.96 % done after 1.3 minutes
# 9.97 % done after 1.4 minutes
# 9.98 % done after 1.4 minutes
# 9.99 % done after 1.4 minutes
# 10.0 % done after 1.4 minutes
# 10.01 % done after 1.4 minutes
# 10.02 % done after 1.4 minutes
# 10.03 % done after 1.4 minutes
# 10.04 % done after 1.4 minutes
# 10.05 % done after 1.4 minutes
# 10.06 % done after 1.4 minutes
# 10.07 % done after 1.4 minutes
# 10.08 % done after 1.4 minutes
# 10.09 % done after 1.4 minutes
# 10.1 % done after 1.4 minutes
# 10.11 % done after 1.4 minutes
# 10.12 % done after 1.4 minutes
# 10.13 % done after 1.4 minutes
# 10.14 % done after 1.4 minutes
# 10.15 % done after 1.4 minutes
# 10.16 % done after 1.4 minutes
# 10.17 % done after 1.4 minutes
# 10.18 % done after 1.4 minutes
# 10.19 % done after 1.4 minutes
# 10.2 % done after 1.4 minutes
# 10.21 % done after 1.4 minutes
# 10.22 % done after 1.4 minutes
# 10.23 % done after 1.4 minutes
# 10.24 % done after 1.4 minutes
# 10.25 % done after 1.4 minutes
# 10.26 % done after 1.4 minutes
# 10.27 % done after 1.4 minutes
# 10.28 % done after 1.5 minutes
# 10.29 % done after 1.5 minutes
# 10.3 % done after 1.5 minutes
# 10.31 % done after 1.5 minutes
# 10.32 % done after 1.5 minutes
# 10.33 % done after 1.5 minutes
# 10.34 % done after 1.5 minutes
# 10.35 % done after 1.5 minutes
# 10.36 % done after 1.5 minutes
# 10.37 % done after 1.5 minutes
# 10.38 % done after 1.5 minutes
# 10.39 % done after 1.5 minutes
# 10.4 % done after 1.5 minutes
# 10.41 % done after 1.5 minutes
# 10.42 % done after 1.5 minutes
# 10.43 % done after 1.5 minutes
# 10.44 % done after 1.5 minutes
# 10.45 % done after 1.5 minutes
# 10.46 % done after 1.5 minutes
# 10.47 % done after 1.5 minutes
# 10.48 % done after 1.5 minutes
# 10.49 % done after 1.5 minutes
# 10.5 % done after 1.5 minutes
# 10.51 % done after 1.5 minutes
# 10.52 % done after 1.5 minutes
# 10.53 % done after 1.5 minutes
# 10.54 % done after 1.5 minutes
# 10.55 % done after 1.5 minutes
# 10.56 % done after 1.5 minutes
# 10.57 % done after 1.5 minutes
# 10.58 % done after 1.5 minutes
# 10.59 % done after 1.5 minutes
# 10.6 % done after 1.5 minutes
# 10.61 % done after 1.5 minutes
# 10.62 % done after 1.5 minutes
# 10.63 % done after 1.5 minutes
# 10.64 % done after 1.5 minutes
# 10.65 % done after 1.5 minutes
# 10.66 % done after 1.5 minutes
# 10.67 % done after 1.5 minutes
# 10.68 % done after 1.5 minutes
# 10.69 % done after 1.5 minutes
# 10.7 % done after 1.5 minutes
# 10.71 % done after 1.5 minutes
# 10.72 % done after 1.5 minutes
# 10.73 % done after 1.5 minutes
# 10.74 % done after 1.5 minutes
# 10.75 % done after 1.5 minutes
# 10.76 % done after 1.5 minutes
# 10.77 % done after 1.5 minutes
# 10.78 % done after 1.5 minutes
# 10.79 % done after 1.5 minutes
# 10.8 % done after 1.5 minutes
# 10.81 % done after 1.6 minutes
# 10.82 % done after 1.6 minutes
# 10.83 % done after 1.6 minutes
# 10.84 % done after 1.6 minutes
# 10.85 % done after 1.6 minutes
# 10.86 % done after 1.6 minutes
# 10.87 % done after 1.6 minutes
# 10.88 % done after 1.6 minutes
# 10.89 % done after 1.6 minutes
# 10.9 % done after 1.6 minutes
# 10.91 % done after 1.6 minutes
# 10.92 % done after 1.6 minutes
# 10.93 % done after 1.6 minutes
# 10.94 % done after 1.6 minutes
# 10.95 % done after 1.6 minutes
# 10.96 % done after 1.6 minutes
# 10.97 % done after 1.6 minutes
# 10.98 % done after 1.6 minutes
# 10.99 % done after 1.6 minutes
# 11.0 % done after 1.6 minutes
# 11.01 % done after 1.6 minutes
# 11.02 % done after 1.6 minutes
# 11.03 % done after 1.6 minutes
# 11.04 % done after 1.6 minutes
# 11.05 % done after 1.6 minutes
# 11.06 % done after 1.6 minutes
# 11.07 % done after 1.6 minutes
# 11.08 % done after 1.6 minutes
# 11.09 % done after 1.6 minutes
# 11.1 % done after 1.6 minutes
# 11.11 % done after 1.6 minutes
# 11.12 % done after 1.6 minutes
# 11.13 % done after 1.6 minutes
# 11.14 % done after 1.6 minutes
# 11.15 % done after 1.6 minutes
# 11.16 % done after 1.6 minutes
# 11.17 % done after 1.6 minutes
# 11.18 % done after 1.6 minutes
# 11.19 % done after 1.6 minutes
# 11.2 % done after 1.6 minutes
# 11.21 % done after 1.6 minutes
# 11.22 % done after 1.6 minutes
# 11.23 % done after 1.6 minutes
# 11.24 % done after 1.6 minutes
# 11.25 % done after 1.7 minutes
# 11.26 % done after 1.7 minutes
# 11.27 % done after 1.7 minutes
# 11.28 % done after 1.7 minutes
# 11.29 % done after 1.7 minutes
# 11.3 % done after 1.7 minutes
# 11.31 % done after 1.7 minutes
# 11.32 % done after 1.7 minutes
# 11.33 % done after 1.7 minutes
# 11.34 % done after 1.7 minutes
# 11.35 % done after 1.7 minutes
# 11.36 % done after 1.7 minutes
# 11.37 % done after 1.7 minutes
# 11.38 % done after 1.7 minutes
# 11.39 % done after 1.7 minutes
# 11.4 % done after 1.7 minutes
# 11.41 % done after 1.7 minutes
# 11.42 % done after 1.7 minutes
# 11.43 % done after 1.7 minutes
# 11.44 % done after 1.7 minutes
# 11.45 % done after 1.7 minutes
# 11.46 % done after 1.7 minutes
# 11.47 % done after 1.7 minutes
# 11.48 % done after 1.7 minutes
# 11.49 % done after 1.7 minutes
# 11.5 % done after 1.7 minutes
# 11.51 % done after 1.7 minutes
# 11.52 % done after 1.7 minutes
# 11.53 % done after 1.7 minutes
# 11.54 % done after 1.7 minutes
# 11.55 % done after 1.7 minutes
# 11.56 % done after 1.7 minutes
# 11.57 % done after 1.7 minutes
# 11.58 % done after 1.7 minutes
# 11.59 % done after 1.8 minutes
# 11.6 % done after 1.8 minutes
# 11.61 % done after 1.8 minutes
# 11.62 % done after 1.8 minutes
# 11.63 % done after 1.8 minutes
# 11.64 % done after 1.8 minutes
# 11.65 % done after 1.8 minutes
# 11.66 % done after 1.8 minutes
# 11.67 % done after 1.8 minutes
# 11.68 % done after 1.8 minutes
# 11.69 % done after 1.8 minutes
# 11.7 % done after 1.8 minutes
# 11.71 % done after 1.8 minutes
# 11.72 % done after 1.8 minutes
# 11.73 % done after 1.8 minutes
# 11.74 % done after 1.8 minutes
# 11.75 % done after 1.8 minutes
# 11.76 % done after 1.8 minutes
# 11.77 % done after 1.8 minutes
# 11.78 % done after 1.8 minutes
# 11.79 % done after 1.8 minutes
# 11.8 % done after 1.8 minutes
# 11.81 % done after 1.8 minutes
# 11.82 % done after 1.8 minutes
# 11.83 % done after 1.8 minutes
# 11.84 % done after 1.8 minutes
# 11.85 % done after 1.8 minutes
# 11.86 % done after 1.8 minutes
# 11.87 % done after 1.8 minutes
# 11.88 % done after 1.8 minutes
# 11.89 % done after 1.8 minutes
# 11.9 % done after 1.8 minutes
# 11.91 % done after 1.8 minutes
# 11.92 % done after 1.8 minutes
# 11.93 % done after 1.8 minutes
# 11.94 % done after 1.8 minutes
# 11.95 % done after 1.8 minutes
# 11.96 % done after 1.8 minutes
# 11.97 % done after 1.8 minutes
# 11.98 % done after 1.8 minutes
# 11.99 % done after 1.9 minutes
# 12.0 % done after 1.9 minutes
# 12.01 % done after 1.9 minutes
# 12.02 % done after 1.9 minutes
# 12.03 % done after 1.9 minutes
# 12.04 % done after 1.9 minutes
# 12.05 % done after 1.9 minutes
# 12.06 % done after 1.9 minutes
# 12.07 % done after 1.9 minutes
# 12.08 % done after 1.9 minutes
# 12.09 % done after 1.9 minutes
# 12.1 % done after 1.9 minutes
# 12.11 % done after 1.9 minutes
# 12.12 % done after 1.9 minutes
# 12.13 % done after 1.9 minutes
# 12.14 % done after 1.9 minutes
# 12.15 % done after 1.9 minutes
# 12.16 % done after 1.9 minutes
# 12.17 % done after 1.9 minutes
# 12.18 % done after 1.9 minutes
# 12.19 % done after 1.9 minutes
# 12.2 % done after 1.9 minutes
# 12.21 % done after 1.9 minutes
# 12.22 % done after 1.9 minutes
# 12.23 % done after 1.9 minutes
# 12.24 % done after 1.9 minutes
# 12.25 % done after 1.9 minutes
# 12.26 % done after 1.9 minutes
# 12.27 % done after 1.9 minutes
# 12.28 % done after 1.9 minutes
# 12.29 % done after 1.9 minutes
# 12.3 % done after 1.9 minutes
# 12.31 % done after 1.9 minutes
# 12.32 % done after 2.0 minutes
# 12.33 % done after 2.0 minutes
# 12.34 % done after 2.0 minutes
# 12.35 % done after 2.0 minutes
# 12.36 % done after 2.0 minutes
# 12.37 % done after 2.0 minutes
# 12.38 % done after 2.0 minutes
# 12.39 % done after 2.0 minutes
# 12.4 % done after 2.0 minutes
# 12.41 % done after 2.0 minutes
# 12.42 % done after 2.0 minutes
# 12.43 % done after 2.0 minutes
# 12.44 % done after 2.0 minutes
# 12.45 % done after 2.0 minutes
# 12.46 % done after 2.0 minutes
# 12.47 % done after 2.0 minutes
# 12.48 % done after 2.0 minutes
# 12.49 % done after 2.0 minutes
# 12.5 % done after 2.0 minutes
# 12.51 % done after 2.0 minutes
# 12.52 % done after 2.0 minutes
# 12.53 % done after 2.0 minutes
# 12.54 % done after 2.0 minutes
# 12.55 % done after 2.0 minutes
# 12.56 % done after 2.0 minutes
# 12.57 % done after 2.0 minutes
# 12.58 % done after 2.0 minutes
# 12.59 % done after 2.0 minutes
# 12.6 % done after 2.0 minutes
# 12.61 % done after 2.0 minutes
# 12.62 % done after 2.0 minutes
# 12.63 % done after 2.0 minutes
# 12.64 % done after 2.0 minutes
# 12.65 % done after 2.0 minutes
# 12.66 % done after 2.0 minutes
# 12.67 % done after 2.0 minutes
# 12.68 % done after 2.0 minutes
# 12.69 % done after 2.0 minutes
# 12.7 % done after 2.0 minutes
# 12.71 % done after 2.0 minutes
# 12.72 % done after 2.0 minutes
# 12.73 % done after 2.0 minutes
# 12.74 % done after 2.0 minutes
# 12.75 % done after 2.0 minutes
# 12.76 % done after 2.0 minutes
# 12.77 % done after 2.0 minutes
# 12.78 % done after 2.0 minutes
# 12.79 % done after 2.0 minutes
# 12.8 % done after 2.0 minutes
# 12.81 % done after 2.0 minutes
# 12.82 % done after 2.0 minutes
# 12.83 % done after 2.0 minutes
# 12.84 % done after 2.0 minutes
# 12.85 % done after 2.0 minutes
# 12.86 % done after 2.0 minutes
# 12.87 % done after 2.0 minutes
# 12.88 % done after 2.0 minutes
# 12.89 % done after 2.0 minutes
# 12.9 % done after 2.0 minutes
# 12.91 % done after 2.0 minutes
# 12.92 % done after 2.0 minutes
# 12.93 % done after 2.0 minutes
# 12.94 % done after 2.0 minutes
# 12.95 % done after 2.0 minutes
# 12.96 % done after 2.0 minutes
# 12.97 % done after 2.0 minutes
# 12.98 % done after 2.0 minutes
# 12.99 % done after 2.0 minutes
# 13.0 % done after 2.0 minutes
# 13.01 % done after 2.0 minutes
# 13.02 % done after 2.0 minutes
# 13.03 % done after 2.0 minutes
# 13.04 % done after 2.0 minutes
# 13.05 % done after 2.0 minutes
# 13.06 % done after 2.0 minutes
# 13.07 % done after 2.0 minutes
# 13.08 % done after 2.1 minutes
# 13.09 % done after 2.1 minutes
# 13.1 % done after 2.1 minutes
# 13.11 % done after 2.1 minutes
# 13.12 % done after 2.1 minutes
# 13.13 % done after 2.1 minutes
# 13.14 % done after 2.1 minutes
# 13.15 % done after 2.1 minutes
# 13.16 % done after 2.1 minutes
# 13.17 % done after 2.1 minutes
# 13.18 % done after 2.1 minutes
# 13.19 % done after 2.1 minutes
# 13.2 % done after 2.1 minutes
# 13.21 % done after 2.1 minutes
# 13.22 % done after 2.1 minutes
# 13.23 % done after 2.1 minutes
# 13.24 % done after 2.1 minutes
# 13.25 % done after 2.1 minutes
# 13.26 % done after 2.1 minutes
# 13.27 % done after 2.1 minutes
# 13.28 % done after 2.1 minutes
# 13.29 % done after 2.1 minutes
# 13.3 % done after 2.1 minutes
# 13.31 % done after 2.1 minutes
# 13.32 % done after 2.1 minutes
# 13.33 % done after 2.1 minutes
# 13.34 % done after 2.1 minutes
# 13.35 % done after 2.1 minutes
# 13.36 % done after 2.1 minutes
# 13.37 % done after 2.1 minutes
# 13.38 % done after 2.1 minutes
# 13.39 % done after 2.1 minutes
# 13.4 % done after 2.1 minutes
# 13.41 % done after 2.1 minutes
# 13.42 % done after 2.1 minutes
# 13.43 % done after 2.1 minutes
# 13.44 % done after 2.1 minutes
# 13.45 % done after 2.1 minutes
# 13.46 % done after 2.1 minutes
# 13.47 % done after 2.1 minutes
# 13.48 % done after 2.1 minutes
# 13.49 % done after 2.1 minutes
# 13.5 % done after 2.1 minutes
# 13.51 % done after 2.1 minutes
# 13.52 % done after 2.1 minutes
# 13.53 % done after 2.1 minutes
# 13.54 % done after 2.1 minutes
# 13.55 % done after 2.1 minutes
# 13.56 % done after 2.1 minutes
# 13.57 % done after 2.1 minutes
# 13.58 % done after 2.1 minutes
# 13.59 % done after 2.1 minutes
# 13.6 % done after 2.1 minutes
# 13.61 % done after 2.1 minutes
# 13.62 % done after 2.1 minutes
# 13.63 % done after 2.1 minutes
# 13.64 % done after 2.1 minutes
# 13.65 % done after 2.1 minutes
# 13.66 % done after 2.1 minutes
# 13.67 % done after 2.2 minutes
# 13.68 % done after 2.2 minutes
# 13.69 % done after 2.2 minutes
# 13.7 % done after 2.2 minutes
# 13.71 % done after 2.2 minutes
# 13.72 % done after 2.2 minutes
# 13.73 % done after 2.2 minutes
# 13.74 % done after 2.2 minutes
# 13.75 % done after 2.2 minutes
# 13.76 % done after 2.3 minutes
# 13.77 % done after 2.3 minutes
# 13.78 % done after 2.3 minutes
# 13.79 % done after 2.3 minutes
# 13.8 % done after 2.3 minutes
# 13.81 % done after 2.3 minutes
# 13.82 % done after 2.3 minutes
# 13.83 % done after 2.3 minutes
# 13.84 % done after 2.3 minutes
# 13.85 % done after 2.3 minutes
# 13.86 % done after 2.3 minutes
# 13.87 % done after 2.3 minutes
# 13.88 % done after 2.3 minutes
# 13.89 % done after 2.3 minutes
# 13.9 % done after 2.3 minutes
# 13.91 % done after 2.3 minutes
# 13.92 % done after 2.3 minutes
# 13.93 % done after 2.3 minutes
# 13.94 % done after 2.3 minutes
# 13.95 % done after 2.3 minutes
# 13.96 % done after 2.3 minutes
# 13.97 % done after 2.3 minutes
# 13.98 % done after 2.3 minutes
# 13.99 % done after 2.3 minutes
# 14.0 % done after 2.3 minutes
# 14.01 % done after 2.3 minutes
# 14.02 % done after 2.3 minutes
# 14.03 % done after 2.3 minutes
# 14.04 % done after 2.3 minutes
# 14.05 % done after 2.3 minutes
# 14.06 % done after 2.3 minutes
# 14.07 % done after 2.3 minutes
# 14.08 % done after 2.4 minutes
# 14.09 % done after 2.4 minutes
# 14.1 % done after 2.4 minutes
# 14.11 % done after 2.4 minutes
# 14.12 % done after 2.4 minutes
# 14.13 % done after 2.4 minutes
# 14.14 % done after 2.4 minutes
# 14.15 % done after 2.4 minutes
# 14.16 % done after 2.4 minutes
# 14.17 % done after 2.4 minutes
# 14.18 % done after 2.4 minutes
# 14.19 % done after 2.4 minutes
# 14.2 % done after 2.4 minutes
# 14.21 % done after 2.4 minutes
# 14.22 % done after 2.4 minutes
# 14.23 % done after 2.4 minutes
# 14.24 % done after 2.4 minutes
# 14.25 % done after 2.4 minutes
# 14.26 % done after 2.4 minutes
# 14.27 % done after 2.4 minutes
# 14.28 % done after 2.4 minutes
# 14.29 % done after 2.4 minutes
# 14.3 % done after 2.4 minutes
# 14.31 % done after 2.4 minutes
# 14.32 % done after 2.4 minutes
# 14.33 % done after 2.4 minutes
# 14.34 % done after 2.4 minutes
# 14.35 % done after 2.4 minutes
# 14.36 % done after 2.4 minutes
# 14.37 % done after 2.4 minutes
# 14.38 % done after 2.4 minutes
# 14.39 % done after 2.4 minutes
# 14.4 % done after 2.4 minutes
# 14.41 % done after 2.4 minutes
# 14.42 % done after 2.4 minutes
# 14.43 % done after 2.4 minutes
# 14.44 % done after 2.4 minutes
# 14.45 % done after 2.4 minutes
# 14.46 % done after 2.4 minutes
# 14.47 % done after 2.5 minutes
# 14.48 % done after 2.5 minutes
# 14.49 % done after 2.5 minutes
# 14.5 % done after 2.5 minutes
# 14.51 % done after 2.5 minutes
# 14.52 % done after 2.5 minutes
# 14.53 % done after 2.5 minutes
# 14.54 % done after 2.5 minutes
# 14.55 % done after 2.5 minutes
# 14.56 % done after 2.5 minutes
# 14.57 % done after 2.5 minutes
# 14.58 % done after 2.5 minutes
# 14.59 % done after 2.5 minutes
# 14.6 % done after 2.5 minutes
# 14.61 % done after 2.5 minutes
# 14.62 % done after 2.5 minutes
# 14.63 % done after 2.5 minutes
# 14.64 % done after 2.5 minutes
# 14.65 % done after 2.5 minutes
# 14.66 % done after 2.5 minutes
# 14.67 % done after 2.5 minutes
# 14.68 % done after 2.5 minutes
# 14.69 % done after 2.5 minutes
# 14.7 % done after 2.5 minutes
# 14.71 % done after 2.5 minutes
# 14.72 % done after 2.5 minutes
# 14.73 % done after 2.5 minutes
# 14.74 % done after 2.5 minutes
# 14.75 % done after 2.5 minutes
# 14.76 % done after 2.5 minutes
# 14.77 % done after 2.5 minutes
# 14.78 % done after 2.5 minutes
# 14.79 % done after 2.5 minutes
# 14.8 % done after 2.5 minutes
# 14.81 % done after 2.5 minutes
# 14.82 % done after 2.5 minutes
# 14.83 % done after 2.5 minutes
# 14.84 % done after 2.5 minutes
# 14.85 % done after 2.5 minutes
# 14.86 % done after 2.5 minutes
# 14.87 % done after 2.5 minutes
# 14.88 % done after 2.5 minutes
# 14.89 % done after 2.5 minutes
# 14.9 % done after 2.5 minutes
# 14.91 % done after 2.5 minutes
# 14.92 % done after 2.5 minutes
# 14.93 % done after 2.5 minutes
# 14.94 % done after 2.5 minutes
# 14.95 % done after 2.5 minutes
# 14.96 % done after 2.5 minutes
# 14.97 % done after 2.6 minutes
# 14.98 % done after 2.6 minutes
# 14.99 % done after 2.6 minutes
# 15.0 % done after 2.6 minutes
# 15.01 % done after 2.6 minutes
# 15.02 % done after 2.6 minutes
# 15.03 % done after 2.6 minutes
# 15.04 % done after 2.6 minutes
# 15.05 % done after 2.6 minutes
# 15.06 % done after 2.6 minutes
# 15.07 % done after 2.6 minutes
# 15.08 % done after 2.6 minutes
# 15.09 % done after 2.6 minutes
# 15.1 % done after 2.6 minutes
# 15.11 % done after 2.6 minutes
# 15.12 % done after 2.6 minutes
# 15.13 % done after 2.6 minutes
# 15.14 % done after 2.6 minutes
# 15.15 % done after 2.6 minutes
# 15.16 % done after 2.6 minutes
# 15.17 % done after 2.6 minutes
# 15.18 % done after 2.6 minutes
# 15.19 % done after 2.6 minutes
# 15.2 % done after 2.6 minutes
# 15.21 % done after 2.6 minutes
# 15.22 % done after 2.6 minutes
# 15.23 % done after 2.6 minutes
# 15.24 % done after 2.6 minutes
# 15.25 % done after 2.6 minutes
# 15.26 % done after 2.6 minutes
# 15.27 % done after 2.6 minutes
# 15.28 % done after 2.6 minutes
# 15.29 % done after 2.6 minutes
# 15.3 % done after 2.6 minutes
# 15.31 % done after 2.6 minutes
# 15.32 % done after 2.6 minutes
# 15.33 % done after 2.6 minutes
# 15.34 % done after 2.6 minutes
# 15.35 % done after 2.6 minutes
# 15.36 % done after 2.6 minutes
# 15.37 % done after 2.6 minutes
# 15.38 % done after 2.6 minutes
# 15.39 % done after 2.6 minutes
# 15.4 % done after 2.6 minutes
# 15.41 % done after 2.6 minutes
# 15.42 % done after 2.6 minutes
# 15.43 % done after 2.6 minutes
# 15.44 % done after 2.6 minutes
# 15.45 % done after 2.6 minutes
# 15.46 % done after 2.6 minutes
# 15.47 % done after 2.6 minutes
# 15.48 % done after 2.6 minutes
# 15.49 % done after 2.6 minutes
# 15.5 % done after 2.6 minutes
# 15.51 % done after 2.6 minutes
# 15.52 % done after 2.7 minutes
# 15.53 % done after 2.7 minutes
# 15.54 % done after 2.7 minutes
# 15.55 % done after 2.7 minutes
# 15.56 % done after 2.7 minutes
# 15.57 % done after 2.7 minutes
# 15.58 % done after 2.7 minutes
# 15.59 % done after 2.7 minutes
# 15.6 % done after 2.7 minutes
# 15.61 % done after 2.7 minutes
# 15.62 % done after 2.7 minutes
# 15.63 % done after 2.7 minutes
# 15.64 % done after 2.7 minutes
# 15.65 % done after 2.7 minutes
# 15.66 % done after 2.7 minutes
# 15.67 % done after 2.7 minutes
# 15.68 % done after 2.7 minutes
# 15.69 % done after 2.7 minutes
# 15.7 % done after 2.7 minutes
# 15.71 % done after 2.7 minutes
# 15.72 % done after 2.7 minutes
# 15.73 % done after 2.7 minutes
# 15.74 % done after 2.7 minutes
# 15.75 % done after 2.7 minutes
# 15.76 % done after 2.7 minutes
# 15.77 % done after 2.7 minutes
# 15.78 % done after 2.7 minutes
# 15.79 % done after 2.7 minutes
# 15.8 % done after 2.7 minutes
# 15.81 % done after 2.7 minutes
# 15.82 % done after 2.7 minutes
# 15.83 % done after 2.7 minutes
# 15.84 % done after 2.7 minutes
# 15.85 % done after 2.7 minutes
# ...
# 95.12 % done after 24.8 minutes
# 95.13 % done after 24.8 minutes
# 95.14 % done after 24.8 minutes
# 95.15 % done after 24.8 minutes
# 95.16 % done after 24.8 minutes
# 95.17 % done after 24.8 minutes
# 95.18 % done after 24.8 minutes
# 95.19 % done after 24.8 minutes
# 95.2 % done after 24.8 minutes
# 95.21 % done after 24.8 minutes
# 95.22 % done after 24.8 minutes
# 95.23 % done after 24.8 minutes
# 95.24 % done after 24.8 minutes
# 95.25 % done after 24.8 minutes
# 95.26 % done after 24.8 minutes
# 95.27 % done after 24.8 minutes
# 95.28 % done after 24.8 minutes
# 95.29 % done after 24.8 minutes
# 95.3 % done after 24.8 minutes
# 95.31 % done after 24.9 minutes
# 95.32 % done after 24.9 minutes
# 95.33 % done after 24.9 minutes
# 95.34 % done after 24.9 minutes
# 95.35 % done after 24.9 minutes
# 95.36 % done after 24.9 minutes
# 95.37 % done after 24.9 minutes
# 95.38 % done after 24.9 minutes
# 95.39 % done after 24.9 minutes
# 95.4 % done after 24.9 minutes
# 95.41 % done after 24.9 minutes
# 95.42 % done after 24.9 minutes
# 95.43 % done after 24.9 minutes
# 95.44 % done after 24.9 minutes
# 95.45 % done after 24.9 minutes
# 95.46 % done after 25.0 minutes
# 95.47 % done after 25.0 minutes
# 95.48 % done after 25.0 minutes
# 95.49 % done after 25.0 minutes
# 95.5 % done after 25.0 minutes
# 95.51 % done after 25.0 minutes
# 95.52 % done after 25.0 minutes
# 95.53 % done after 25.0 minutes
# 95.54 % done after 25.0 minutes
# 95.55 % done after 25.0 minutes
# 95.56 % done after 25.0 minutes
# 95.57 % done after 25.0 minutes
# 95.58 % done after 25.0 minutes
# 95.59 % done after 25.0 minutes
# 95.6 % done after 25.0 minutes
# 95.61 % done after 25.0 minutes
# 95.62 % done after 25.0 minutes
# 95.63 % done after 25.0 minutes
# 95.64 % done after 25.0 minutes
# 95.65 % done after 25.0 minutes
# 95.66 % done after 25.0 minutes
# 95.67 % done after 25.0 minutes
# 95.68 % done after 25.0 minutes
# 95.69 % done after 25.0 minutes
# 95.7 % done after 25.0 minutes
# 95.71 % done after 25.0 minutes
# 95.72 % done after 25.0 minutes
# 95.73 % done after 25.0 minutes
# 95.74 % done after 25.0 minutes
# 95.75 % done after 25.0 minutes
# 95.76 % done after 25.0 minutes
# 95.77 % done after 25.0 minutes
# 95.78 % done after 25.0 minutes
# 95.79 % done after 25.0 minutes
# 95.8 % done after 25.0 minutes
# 95.81 % done after 25.0 minutes
# 95.82 % done after 25.0 minutes
# 95.83 % done after 25.1 minutes
# 95.84 % done after 25.1 minutes
# 95.85 % done after 25.1 minutes
# 95.86 % done after 25.1 minutes
# 95.87 % done after 25.1 minutes
# 95.88 % done after 25.1 minutes
# 95.89 % done after 25.1 minutes
# 95.9 % done after 25.1 minutes
# 95.91 % done after 25.1 minutes
# 95.92 % done after 25.1 minutes
# 95.93 % done after 25.1 minutes
# 95.94 % done after 25.1 minutes
# 95.95 % done after 25.1 minutes
# 95.96 % done after 25.1 minutes
# 95.97 % done after 25.1 minutes
# 95.98 % done after 25.1 minutes
# 95.99 % done after 25.1 minutes
# 96.0 % done after 25.1 minutes
# 96.01 % done after 25.1 minutes
# 96.02 % done after 25.1 minutes
# 96.03 % done after 25.1 minutes
# 96.04 % done after 25.1 minutes
# 96.05 % done after 25.1 minutes
# 96.06 % done after 25.1 minutes
# 96.07 % done after 25.1 minutes
# 96.08 % done after 25.1 minutes
# 96.09 % done after 25.1 minutes
# 96.1 % done after 25.1 minutes
# 96.11 % done after 25.1 minutes
# 96.12 % done after 25.1 minutes
# 96.13 % done after 25.1 minutes
# 96.14 % done after 25.1 minutes
# 96.15 % done after 25.1 minutes
# 96.16 % done after 25.1 minutes
# 96.17 % done after 25.1 minutes
# 96.18 % done after 25.1 minutes
# 96.19 % done after 25.1 minutes
# 96.2 % done after 25.1 minutes
# 96.21 % done after 25.1 minutes
# 96.22 % done after 25.1 minutes
# 96.23 % done after 25.1 minutes
# 96.24 % done after 25.1 minutes
# 96.25 % done after 25.1 minutes
# 96.26 % done after 25.1 minutes
# 96.27 % done after 25.1 minutes
# 96.28 % done after 25.1 minutes
# 96.29 % done after 25.1 minutes
# 96.3 % done after 25.1 minutes
# 96.31 % done after 25.1 minutes
# 96.32 % done after 25.1 minutes
# 96.33 % done after 25.1 minutes
# 96.34 % done after 25.1 minutes
# 96.35 % done after 25.1 minutes
# 96.36 % done after 25.1 minutes
# 96.37 % done after 25.1 minutes
# 96.38 % done after 25.1 minutes
# 96.39 % done after 25.2 minutes
# 96.4 % done after 25.2 minutes
# 96.41 % done after 25.2 minutes
# 96.42 % done after 25.2 minutes
# 96.43 % done after 25.2 minutes
# 96.44 % done after 25.2 minutes
# 96.45 % done after 25.2 minutes
# 96.46 % done after 25.2 minutes
# 96.47 % done after 25.2 minutes
# 96.48 % done after 25.2 minutes
# 96.49 % done after 25.2 minutes
# 96.5 % done after 25.2 minutes
# 96.51 % done after 25.2 minutes
# 96.52 % done after 25.2 minutes
# 96.53 % done after 25.2 minutes
# 96.54 % done after 25.2 minutes
# 96.55 % done after 25.2 minutes
# 96.56 % done after 25.2 minutes
# 96.57 % done after 25.2 minutes
# 96.58 % done after 25.2 minutes
# 96.59 % done after 25.2 minutes
# 96.6 % done after 25.2 minutes
# 96.61 % done after 25.2 minutes
# 96.62 % done after 25.2 minutes
# 96.63 % done after 25.2 minutes
# 96.64 % done after 25.2 minutes
# 96.65 % done after 25.2 minutes
# 96.66 % done after 25.2 minutes
# 96.67 % done after 25.2 minutes
# 96.68 % done after 25.2 minutes
# 96.69 % done after 25.2 minutes
# 96.7 % done after 25.2 minutes
# 96.71 % done after 25.2 minutes
# 96.72 % done after 25.2 minutes
# 96.73 % done after 25.2 minutes
# 96.74 % done after 25.2 minutes
# 96.75 % done after 25.2 minutes
# 96.76 % done after 25.3 minutes
# 96.77 % done after 25.3 minutes
# 96.78 % done after 25.3 minutes
# 96.79 % done after 25.3 minutes
# 96.8 % done after 25.3 minutes
# 96.81 % done after 25.3 minutes
# 96.82 % done after 25.3 minutes
# 96.83 % done after 25.3 minutes
# 96.84 % done after 25.3 minutes
# 96.85 % done after 25.3 minutes
# 96.86 % done after 25.3 minutes
# 96.87 % done after 25.3 minutes
# 96.88 % done after 25.3 minutes
# 96.89 % done after 25.3 minutes
# 96.9 % done after 25.3 minutes
# 96.91 % done after 25.3 minutes
# 96.92 % done after 25.3 minutes
# 96.93 % done after 25.3 minutes
# 96.94 % done after 25.3 minutes
# 96.95 % done after 25.3 minutes
# 96.96 % done after 25.3 minutes
# 96.97 % done after 25.3 minutes
# 96.98 % done after 25.3 minutes
# 96.99 % done after 25.3 minutes
# 97.0 % done after 25.3 minutes
# 97.01 % done after 25.3 minutes
# 97.02 % done after 25.3 minutes
# 97.03 % done after 25.3 minutes
# 97.04 % done after 25.3 minutes
# 97.05 % done after 25.3 minutes
# 97.06 % done after 25.3 minutes
# 97.07 % done after 25.3 minutes
# 97.08 % done after 25.3 minutes
# 97.09 % done after 25.3 minutes
# 97.1 % done after 25.3 minutes
# 97.11 % done after 25.3 minutes
# 97.12 % done after 25.3 minutes
# 97.13 % done after 25.3 minutes
# 97.14 % done after 25.3 minutes
# 97.15 % done after 25.4 minutes
# 97.16 % done after 25.4 minutes
# 97.17 % done after 25.4 minutes
# 97.18 % done after 25.4 minutes
# 97.19 % done after 25.4 minutes
# 97.2 % done after 25.4 minutes
# 97.21 % done after 25.4 minutes
# 97.22 % done after 25.4 minutes
# 97.23 % done after 25.4 minutes
# 97.24 % done after 25.4 minutes
# 97.25 % done after 25.4 minutes
# 97.26 % done after 25.4 minutes
# 97.27 % done after 25.4 minutes
# 97.28 % done after 25.4 minutes
# 97.29 % done after 25.4 minutes
# 97.3 % done after 25.4 minutes
# 97.31 % done after 25.4 minutes
# 97.32 % done after 25.4 minutes
# 97.33 % done after 25.4 minutes
# 97.34 % done after 25.4 minutes
# 97.35 % done after 25.4 minutes
# 97.36 % done after 25.4 minutes
# 97.37 % done after 25.4 minutes
# 97.38 % done after 25.4 minutes
# 97.39 % done after 25.4 minutes
# 97.4 % done after 25.4 minutes
# 97.41 % done after 25.4 minutes
# 97.42 % done after 25.4 minutes
# 97.43 % done after 25.4 minutes
# 97.44 % done after 25.5 minutes
# 97.45 % done after 25.5 minutes
# 97.46 % done after 25.5 minutes
# 97.47 % done after 25.5 minutes
# 97.48 % done after 25.5 minutes
# 97.49 % done after 25.5 minutes
# 97.5 % done after 25.5 minutes
# 97.51 % done after 25.5 minutes
# 97.52 % done after 25.5 minutes
# 97.53 % done after 25.5 minutes
# 97.54 % done after 25.5 minutes
# 97.55 % done after 25.5 minutes
# 97.56 % done after 25.5 minutes
# 97.57 % done after 25.5 minutes
# 97.58 % done after 25.5 minutes
# 97.59 % done after 25.5 minutes
# 97.6 % done after 25.5 minutes
# 97.61 % done after 25.5 minutes
# 97.62 % done after 25.5 minutes
# 97.63 % done after 25.5 minutes
# 97.64 % done after 25.5 minutes
# 97.65 % done after 25.5 minutes
# 97.66 % done after 25.5 minutes
# 97.67 % done after 25.5 minutes
# 97.68 % done after 25.5 minutes
# 97.69 % done after 25.5 minutes
# 97.7 % done after 25.5 minutes
# 97.71 % done after 25.5 minutes
# 97.72 % done after 25.5 minutes
# 97.73 % done after 25.5 minutes
# 97.74 % done after 25.5 minutes
# 97.75 % done after 25.5 minutes
# 97.76 % done after 25.5 minutes
# 97.77 % done after 25.5 minutes
# 97.78 % done after 25.6 minutes
# 97.79 % done after 25.6 minutes
# 97.8 % done after 25.6 minutes
# 97.81 % done after 25.6 minutes
# 97.82 % done after 25.6 minutes
# 97.83 % done after 25.6 minutes
# 97.84 % done after 25.6 minutes
# 97.85 % done after 25.6 minutes
# 97.86 % done after 25.6 minutes
# 97.87 % done after 25.6 minutes
# 97.88 % done after 25.6 minutes
# 97.89 % done after 25.6 minutes
# 97.9 % done after 25.6 minutes
# 97.91 % done after 25.6 minutes
# 97.92 % done after 25.6 minutes
# 97.93 % done after 25.6 minutes
# 97.94 % done after 25.6 minutes
# 97.95 % done after 25.6 minutes
# 97.96 % done after 25.6 minutes
# 97.97 % done after 25.6 minutes
# 97.98 % done after 25.6 minutes
# 97.99 % done after 25.6 minutes
# 98.0 % done after 25.6 minutes
# 98.01 % done after 25.6 minutes
# 98.02 % done after 25.6 minutes
# 98.03 % done after 25.6 minutes
# 98.04 % done after 25.7 minutes
# 98.05 % done after 25.7 minutes
# 98.06 % done after 25.7 minutes
# 98.07 % done after 25.7 minutes
# 98.08 % done after 25.7 minutes
# 98.09 % done after 25.7 minutes
# 98.1 % done after 25.7 minutes
# 98.11 % done after 25.7 minutes
# 98.12 % done after 25.7 minutes
# 98.13 % done after 25.7 minutes
# 98.14 % done after 25.7 minutes
# 98.15 % done after 25.7 minutes
# 98.16 % done after 25.7 minutes
# 98.17 % done after 25.7 minutes
# 98.18 % done after 25.7 minutes
# 98.19 % done after 25.7 minutes
# 98.2 % done after 25.7 minutes
# 98.21 % done after 25.7 minutes
# 98.22 % done after 25.7 minutes
# 98.23 % done after 25.7 minutes
# 98.24 % done after 25.7 minutes
# 98.25 % done after 25.7 minutes
# 98.26 % done after 25.7 minutes
# 98.27 % done after 25.7 minutes
# 98.28 % done after 25.7 minutes
# 98.29 % done after 25.7 minutes
# 98.3 % done after 25.7 minutes
# 98.31 % done after 25.8 minutes
# 98.32 % done after 25.8 minutes
# 98.33 % done after 25.8 minutes
# 98.34 % done after 25.8 minutes
# 98.35 % done after 25.8 minutes
# 98.36 % done after 25.8 minutes
# 98.37 % done after 25.8 minutes
# 98.38 % done after 25.8 minutes
# 98.39 % done after 25.8 minutes
# 98.4 % done after 25.8 minutes
# 98.41 % done after 25.8 minutes
# 98.42 % done after 25.8 minutes
# 98.43 % done after 25.8 minutes
# 98.44 % done after 25.8 minutes
# 98.45 % done after 25.8 minutes
# 98.46 % done after 25.8 minutes
# 98.47 % done after 25.8 minutes
# 98.48 % done after 25.8 minutes
# 98.49 % done after 25.8 minutes
# 98.5 % done after 25.8 minutes
# 98.51 % done after 25.8 minutes
# 98.52 % done after 25.8 minutes
# 98.53 % done after 25.8 minutes
# 98.54 % done after 25.8 minutes
# 98.55 % done after 25.8 minutes
# 98.56 % done after 25.8 minutes
# 98.57 % done after 25.8 minutes
# 98.58 % done after 25.8 minutes
# 98.59 % done after 25.8 minutes
# 98.6 % done after 25.8 minutes
# 98.61 % done after 25.8 minutes
# 98.62 % done after 25.8 minutes
# 98.63 % done after 25.8 minutes
# 98.64 % done after 25.8 minutes
# 98.65 % done after 25.8 minutes
# 98.66 % done after 25.8 minutes
# 98.67 % done after 25.8 minutes
# 98.68 % done after 25.8 minutes
# 98.69 % done after 25.8 minutes
# 98.7 % done after 25.8 minutes
# 98.71 % done after 25.8 minutes
# 98.72 % done after 25.8 minutes
# 98.73 % done after 25.8 minutes
# 98.74 % done after 25.8 minutes
# 98.75 % done after 25.8 minutes
# 98.76 % done after 25.9 minutes
# 98.77 % done after 25.9 minutes
# 98.78 % done after 25.9 minutes
# 98.79 % done after 25.9 minutes
# 98.8 % done after 25.9 minutes
# 98.81 % done after 25.9 minutes
# 98.82 % done after 25.9 minutes
# 98.83 % done after 25.9 minutes
# 98.84 % done after 25.9 minutes
# 98.85 % done after 25.9 minutes
# 98.86 % done after 25.9 minutes
# 98.87 % done after 25.9 minutes
# 98.88 % done after 25.9 minutes
# 98.89 % done after 25.9 minutes
# 98.9 % done after 25.9 minutes
# 98.91 % done after 25.9 minutes
# 98.92 % done after 25.9 minutes
# 98.93 % done after 25.9 minutes
# 98.94 % done after 25.9 minutes
# 98.95 % done after 25.9 minutes
# 98.96 % done after 25.9 minutes
# 98.97 % done after 25.9 minutes
# 98.98 % done after 25.9 minutes
# 98.99 % done after 25.9 minutes
# 99.0 % done after 25.9 minutes
# 99.01 % done after 25.9 minutes
# 99.02 % done after 25.9 minutes
# 99.03 % done after 25.9 minutes
# 99.04 % done after 25.9 minutes
# 99.05 % done after 25.9 minutes
# 99.06 % done after 25.9 minutes
# 99.07 % done after 25.9 minutes
# 99.08 % done after 25.9 minutes
# 99.09 % done after 25.9 minutes
# 99.1 % done after 25.9 minutes
# 99.11 % done after 25.9 minutes
# 99.12 % done after 25.9 minutes
# 99.13 % done after 25.9 minutes
# 99.14 % done after 25.9 minutes
# 99.15 % done after 25.9 minutes
# 99.16 % done after 26.0 minutes
# 99.17 % done after 26.0 minutes
# 99.18 % done after 26.0 minutes
# 99.19 % done after 26.0 minutes
# 99.2 % done after 26.0 minutes
# 99.21 % done after 26.0 minutes
# 99.22 % done after 26.0 minutes
# 99.23 % done after 26.0 minutes
# 99.24 % done after 26.0 minutes
# 99.25 % done after 26.0 minutes
# 99.26 % done after 26.0 minutes
# 99.27 % done after 26.0 minutes
# 99.28 % done after 26.0 minutes
# 99.29 % done after 26.0 minutes
# 99.3 % done after 26.0 minutes
# 99.31 % done after 26.0 minutes
# 99.32 % done after 26.0 minutes
# 99.33 % done after 26.0 minutes
# 99.34 % done after 26.0 minutes
# 99.35 % done after 26.0 minutes
# 99.36 % done after 26.0 minutes
# 99.37 % done after 26.0 minutes
# 99.38 % done after 26.0 minutes
# 99.39 % done after 26.0 minutes
# 99.4 % done after 26.0 minutes
# 99.41 % done after 26.0 minutes
# 99.42 % done after 26.0 minutes
# 99.43 % done after 26.0 minutes
# 99.44 % done after 26.1 minutes
# 99.45 % done after 26.1 minutes
# 99.46 % done after 26.1 minutes
# 99.47 % done after 26.1 minutes
# 99.48 % done after 26.1 minutes
# 99.49 % done after 26.1 minutes
# 99.5 % done after 26.1 minutes
# 99.51 % done after 26.1 minutes
# 99.52 % done after 26.1 minutes
# 99.53 % done after 26.1 minutes
# 99.54 % done after 26.1 minutes
# 99.55 % done after 26.1 minutes
# 99.56 % done after 26.1 minutes
# 99.57 % done after 26.1 minutes
# 99.58 % done after 26.1 minutes
# 99.59 % done after 26.1 minutes
# 99.6 % done after 26.1 minutes
# 99.61 % done after 26.1 minutes
# 99.62 % done after 26.1 minutes
# 99.63 % done after 26.1 minutes
# 99.64 % done after 26.1 minutes
# 99.65 % done after 26.1 minutes
# 99.66 % done after 26.1 minutes
# 99.67 % done after 26.1 minutes
# 99.68 % done after 26.1 minutes
# 99.69 % done after 26.1 minutes
# 99.7 % done after 26.1 minutes
# 99.71 % done after 26.1 minutes
# 99.72 % done after 26.1 minutes
# 99.73 % done after 26.1 minutes
# 99.74 % done after 26.1 minutes
# 99.75 % done after 26.1 minutes
# 99.76 % done after 26.1 minutes
# 99.77 % done after 26.1 minutes
# 99.78 % done after 26.1 minutes
# 99.79 % done after 26.1 minutes
# 99.8 % done after 26.2 minutes
# 99.81 % done after 26.2 minutes
# 99.82 % done after 26.2 minutes
# 99.83 % done after 26.2 minutes
# 99.84 % done after 26.2 minutes
# 99.85 % done after 26.2 minutes
# 99.86 % done after 26.2 minutes
# 99.87 % done after 26.2 minutes
# 99.88 % done after 26.2 minutes
# 99.89 % done after 26.2 minutes
# 99.9 % done after 26.2 minutes
# 99.91 % done after 26.2 minutes
# 99.92 % done after 26.2 minutes
# 99.93 % done after 26.2 minutes
# 99.94 % done after 26.2 minutes
# 99.95 % done after 26.2 minutes
# 99.96 % done after 26.2 minutes
# 99.97 % done after 26.2 minutes
# 99.98 % done after 26.2 minutes
# 99.99 % done after 26.2 minutes
# 100.0 % done after 26.2 minutes
# /var/folders/rr/dkr55psd2qsf541m2wnpzv0c0000gn/T/ipykernel_54818/4165817259.py:49: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sequences = np.array(data[5])

# %%
natural_indices = get_natural_proteins(sequences)[1] # getting the indices of the natural sequences

natural_sequences = sequences[natural_indices] # making a list of all natural sequences

converted_sequences = convert_sequences(natural_sequences) # converting the natural sequences to abbreviated form

# %%
nat_names = names[natural_indices]
nat_length = length[natural_indices]
nat_chains = chains[natural_indices]
nat_helices = helices[natural_indices]
nat_sheets = sheets[natural_indices]
nat_sequences = converted_sequences

# %%
import pandas as pd

df = pd.DataFrame(list(zip(nat_names, nat_sequences, nat_length, nat_chains, nat_helices, nat_sheets)), columns = ["names", "sequences", "length", "chains", "helices", "sheets"])
df.to_csv("training_data.csv")   # create csv

df = pd.read_csv("training_data.csv")  # read csv
df.shape
# Out:
# (1525, 7)

# %%
################################################################################################################

# %%
# FUNCTION TO GET DATA 2 (get proteins less than xxx long)

import os, glob, time

def protein_info(directory, total_files, max_length):  # inputs: directory, total_files, max length of sequence
    
    helices = []
    sheets = []
    sequences = []
    name = []
    length = []
    chains = []
    
    t0 = time.time()
    
    counter = 0
    
    for filename in glob.glob(directory):
        
        f = os.path.join(directory, filename)

        # checking if it is a file and that the sequence length is within the limit
        if os.path.isfile(f) and len(seq_getter(f)[0]) <= max_length:
            
            counts = check(f)  # getting the number of sheets and helices
            sequence_data = seq_getter(f)  # getting the sequence data
            
            helices.append(counts[0])
            sheets.append(counts[1])
            sequences.append(sequence_data[0])
            name.append(filename)
            length.append(len(sequence_data[0]))
            chains.append(len(sequence_data[1]))
            
            counter = counter + 1
            print(round(counter/total_files*100, 2), "% done", "after", round((time.time()-t0)/60, 1), "minutes")
            
        if counter == total_files:   
            break
                     
            
    return name, length, chains, helices, sheets, sequences


directory = "/Volumes/UCG Hard D./PDB Files/pdb//*//*.ent"
data = protein_info(directory, 5000, 1000)

names = data[0]
length = data[1]
chains = data[2]
helices = data[3]
sheets = data[4]
sequences = data[5]

# %%
import pandas as pd

df = pd.DataFrame(list(zip(names, sequences, length, chains, helices, sheets)), columns = ["names", "sequences", "length", "chains", "helices", "sheets"])
df.to_csv("proteins_5000.csv")   # create csv
df = pd.read_csv("proteins_5000.csv")  # read csv
df.head()

# %%
# the code that gives a different number of sheets



dic={}
strands=[]

PDB=open("/Users/maxschaffelder/Desktop/Project_Year_2/pdb/fold_3/pdb1b5h.pdb", "r")
file=PDB.readlines()
for line in file:
    if "SHEET" in line[0:6]:
        initSeqNum=line[22:26]
        endSeqNum=line[33:37]
        chainID=line[21:22]
        sheetID=line[11:14]
        strands.append((initSeqNum, endSeqNum, chainID))
        if sheetID not in dic.keys():
            dic[sheetID]=[(initSeqNum, endSeqNum, chainID)]
        else:
            if (initSeqNum, endSeqNum, chainID) not in dic[sheetID]:
                dic[sheetID].append((initSeqNum, endSeqNum, chainID))
PDB.close()

print("The number of sheets in this protein is", len(dic))


helix_no=0
# Total length of all helices used to calculate the average length of a helix.
total_hel_length=0

PDB=open("/Users/maxschaffelder/Desktop/Project_Year_2/pdb/fold_3/pdb1b5h.pdb", "r")
file=PDB.readlines()
print("helixID" + "\t\t" + "length")
for line in file:
    if "HELIX" in line[0:6]: 
        helix_len=line[71:76]
        helix_id=line[11:14]
        total_hel_length+=int(helix_len)
        helix_no+=1
        #print(helix_id + "\t\t" + helix_len)        
PDB.close()

print("\nThere are", helix_no, "alpha-helices in this protein")
# Out:
# The number of sheets in this protein is 6
# helixID		length
#
# There are 23 alpha-helices in this protein

# %%
check("/Users/maxschaffelder/Desktop/Project_Year_2/pdb/fold_3/pdb1b5h.pdb")
# Out:
# (23, 6)
